# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 12.6 MB 4.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 507 kB 5.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 346 kB 23.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 21.2 MB 46.3 MB/s eta 0:00:01   |██▊                             | 1.8 MB 1.7 MB/s eta 0:00:12     |███▏                            | 2.1 MB 1.7 MB/s eta 0:00:12     |███████                         | 4.6 MB 1.7 MB/s eta 0:00:10
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 294 kB 3.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.9 MB 4.0 MB/s eta 0:00:01     |█▋                              | 409 kB 4.0 MB/s eta 0:00:02
# ...
#      |████████████████████████████████| 2.3 MB 8.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 65 kB 6.1 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 265 kB 5.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.2 MB 17.8 MB/s eta 0:00:01     |██████████████████▋             | 1.9 MB 17.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 107 kB 24.6 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv('police_deaths_USA_v6 (1).csv')

# %%
df
# Out:
#                       Rank                    Name   Age End_Of_Watch  \
# 0                Constable           Darius Quimby   NaN   1791-01-03
# 1                  Sheriff      Cornelius Hogeboom  53.0   1791-10-22
# 2           Deputy Sheriff             Isaac Smith   NaN   1792-05-17
# 3                  Marshal          Robert Forsyth  40.0   1794-01-11
# 4           Deputy Sheriff          Robert Berwick   NaN   1797-06-29
# ...                    ...                     ...   ...          ...
# 2516  Correctional Officer    Frank Bonham Ferrell   NaN   1902-06-09
# 2517               Sheriff  Andrew Jackson Bullard   NaN   1902-06-30
# 2518        Police Officer      James William Finn  49.0   1902-06-03
# 2519        Deputy Sheriff            John Cogburn   NaN   1902-06-30
# 2520        Deputy Marshal           Thomas Nalley  28.0   1902-10-14
#
#      Day_Of_Week           Cause  \
# 0         Monday         Stabbed
# 1       Saturday         Gunfire
# ...

# %%
plt.figure(figsize=(12, 12))  # Width = 12, Height = 6
ax = sns.barplot(df.groupby('State').count()[['Rank']].sort_values('Rank', ascending=False), x="Rank", y="State",legend=False)
ax.bar_label(ax.containers[0], fontsize=10);
plt.show()

# %%
plt.figure(figsize=(12, 12))  # Width = 12, Height = 6
ax = sns.barplot(df.groupby('Cause').count()[['Rank']].sort_values('Rank', ascending=False), x="Rank", y="Cause",legend=False)
ax.bar_label(ax.containers[0], fontsize=10);
plt.show()

# %%
plt.figure(figsize=(12, 12))  # Width = 12, Height = 6
ax = sns.barplot(df.groupby('Day_Of_Week').count()[['Rank']].sort_values('Rank', ascending=False), x="Day_Of_Week", y="Rank",legend=False)
ax.bar_label(ax.containers[0], fontsize=10);
plt.show()

# %%
df.groupby('State').count()[['Rank']].reset_index()
# Out:
#                    State  Rank
# 0                Alabama    49
# 1                Arizona    32
# 2               Arkansas    32
# 3             California    91
# 4               Colorado    58
# 5            Connecticut    12
# 6               Delaware     5
# 7   District of Columbia     7
# 8                Florida    47
# 9                Georgia    61
# 10                Hawaii     1
# 11                 Idaho     4
# 12              Illinois   102
# 13               Indiana    32
# 14                  Iowa    31
# 15                Kansas    65
# 16              Kentucky   141
# 17             Louisiana    55
# 18                 Maine    13
# 19              Maryland    30
# 20         Massachusetts    32
# 21              Michigan    24
# 22             Minnesota    18
# 23           Mississippi    16
# 24              Missouri   114
# 25               Montana    17
# 26              Nebraska    13
# 27                Nevada    16
# 28         New Hampshire     6
# ...

# %%
df.groupby('Cause').count()['Rank'].hist()
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2521 entries, 0 to 2520
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          2521 non-null   object
#  1   Name          2521 non-null   object
#  2   Age           1818 non-null   float64
#  3   End_Of_Watch  2521 non-null   object
#  4   Day_Of_Week   2521 non-null   object
#  5   Cause         2520 non-null   object
#  6   Department    2521 non-null   object
#  7   State         2521 non-null   object
#  8   Tour          1044 non-null   object
#  9   Badge         133 non-null    object
#  10  Weapon        2183 non-null   object
#  11  Offender      1646 non-null   object
#  12  Summary       2521 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 256.2+ KB
